# %% [markdown]
# <a href="https://colab.research.google.com/github/KauaVarane/Exercicios-Python-Fatec/blob/main/Lista_de_exercicios_Kau%C3%A3_Santos_Gomes_Varane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1-)
lado=int(input("Digite lado do quadrado:"))
area=(lado*lado)
print("Área do quadrado é:",area)

# %%
# 2-)
salario_inicial=int(input("Digite salário:"))
salario_reajuste=(salario_inicial+(salario_inicial*0.15))
print("O novo Salário será:",salario_reajuste)

# %%
# 3-)
base_triangulo=int(input("Digite a base do triângulo:"))
altura_triangulo=int(input("Digite a altura do triângulo:"))
area_total=((base_triangulo*altura_triangulo)/2)
print("Área do total do triângulo é:",area_total)

# %%
# 4-)
graus=int(input("Digite Graus Celsius:"))
fahrenheit=((9*graus+160)/5)
print("A temperatura em fahrenheit é:",fahrenheit)

# %%
# 5-)
import math
a=int(input("Digite valor A: "))
b=int(input("Digite valor B: "))
c=int(input("Digite valor C: "))
delta = (b ** 2) - (4 * a * c)
x1=(-b + math.sqrt(delta)) / (2 * a)
x2=(-b - math.sqrt(delta)) / (2 * a)
print("O resultado da equação será:")
print("X1:", round(x1, 2))
print("X2:", round(x2, 2))

# %%
# 6-)
x=int(input("Digite valor X:"))
y=int(input("Digite valor Y:"))
z=(x)
p=(y)
y=(z)
x=(p)
print("X:",x)
print("Y:",y)

# %%
# 7-)
c=int(input("Digite valor do Comprimento:"))
a=int(input("Digite valor da Altura:"))
l=int(input("Digite valor da Largura:"))
volume=(c*l*a)
print("Volume é igual:",volume)

# %%
# 8-)
d=float(input("Digite valor do Depósito:"))
r=(d+(d*0.013))
print("Rendimetno é igual:",r)

# %%
# 9-)
n1=int(input("Digite o Primeiro número:"))
n2=int(input("Digite o Segundo número:"))
q1=(n1*n1)
q2=(n2*n2)
s=(q1+q2)
print("A soma do Quadrados é igual:",s)

# %%
# 10-)
n1=int(input("Digite o Primeiro número:"))
n2=int(input("Digite o Segundo número:"))
if n1>n2:
  d=(n1-n2)
else:
  d=(n2-n1)
print("A Diferença é:",d)

# %%
# 11-)
r=int(input("Digite o Raio da Circuferência:"))
c=(2*3.14*r)
print("O Comprimento da Circuferência:", round(c, 2))

# %%
# 12-)
an=int(input("Digite o Ano de Nascimetno:"))
at=int(input("Digite o Ano de Atual:"))
i=(at-an)
id_depois_17_anos=(i+17)
print("Sua idade atual:",i)
print("Daqui 17 anos sua idade será:",id_depois_17_anos)

# %%
# 13-)
qakg=int(input("Digite quantidade de alimentos(kg):"))
g=(qakg*1000)
cd=(50)
d=(g/cd)
print("Os alimentos ira durar:",d,"Dias")

# %%
# 14-)
a1=int(input("Digite Ângulo 1:"))
a2=int(input("Digite Ângulo 2:"))
a3=((a1+a2)-180)
print("O valor do Ângulo 3 será:",a3)

# %%
# 15-)
c1=int(input("Digite Cateto 1:"))
c2=int(input("Digite Cateto 2:"))
h=((c1*c1)+(c2*c2))
print("O valor da Hipotenusa será:",h)

# %%
# 16-)
ht=float(input("Digite quantidade de horas trablhadas:"))
vh=float(input("Digite o Valor por hora:"))
pd=float(input("Digite o Percentual de desconto:"))
dependentes=float(input("Digite o valor de Dependentes:"))
salario=(ht*vh)
salario_liquido=(salario-pd)
d=(salario_liquido+(dependentes*100))
print("O valor do salário a receber será:",d)

# %%
# 17-)
tp=int(input("Tempo de percurso(horas):"))
vm=int(input("Velocidade média:"))
dt=(tp*vm)
lg=(dt/12)
print("A quantidade de Litros gastos será:",round(lg,2))

# %%
# 18-)
v1=int(input("Digite o Valor 1:"))
v2=int(input("Digite o Valor 2:"))
if v1 > v2:
  resultado=int
  resultado=(v1-v2)
  print("O maior valor é:",v1)
  print("A Diferença entre os valores é:",r)
else:
  resultado=(v2-v1)
  print("O maior valor é:",v2)
  print("A Diferença entre os valores é:",r)

# %%
# 19-)
n1=float(input("Digite um número:"))
n2=float(input("Digite outro numero:"))
if n1>n2:
  print("O maior valor é:",n1)
else:
  print("O maior valor é:",n2)

# %%
import math

# Entrada dos coeficientes
A = float(input("Digite o valor de A: "))
B = float(input("Digite o valor de B: "))
C = float(input("Digite o valor de C: "))

if A == 0:
    print("Isso não é uma equação do 2º grau.")
else:
    delta = B**2 - 4*A*C
    print("Delta =", delta)  # Mostra o valor do discriminante

    if delta < 0:
        print("A equação não possui raízes reais.")
    elif delta == 0:
        x = -B / (2*A)
        print("A equação possui uma raiz real: x =", x)
    else:
        x1 = (-B + math.sqrt(delta)) / (2*A)
        x2 = (-B - math.sqrt(delta)) / (2*A)
        print("A equação possui duas raízes reais: x1 =", x1, "e x2 =", x2)

# %%
# 21-)
n1=float(input("Digite a Primeira nota:"))
n2=float(input("Digite a Segunda nota:"))
n3=float(input("Digite a Terceira nota:"))
n4=float(input("Digite a Quarta nota:"))
media=((n1+n2+n3+n4)/4)
if media>=6:
  print("Você foi Aprovado, sua nota foi:",media)
else:
  if media>=3<6:
    print("Você está de Exame, sua nota foi:",media)
  else:
    print("Você está Retido, sua nota foi:",media)

# %%
# 22-)
n1=int(input("Digite um número:"))
n2=int(input("Digite um número(diferente do primeiro):"))
if n1>n2:
  print("A ordem crescente dos números é:",n2,n1)
else:
  print("A ordem crescente dos números é:",n1,n2)

# %%
# 23-)
n1=int(input("Digite um número:"))
n2=int(input("Digite um número(valor maior que o Primeiro):"))
n3=int(input("Digite um número(valor maior que o Segundo):"))
n4=int(input("Digite um número Aleatório:"))
if n4>n3:
  print("A ordem crescente dos números é:",n1,n2,n3,n4)
else:
  if n2<n4<n3:
    print("A ordem crescente dos números é:",n1,n2,n4,n3)
  else:
    if n1<n4<n2:
      print("A ordem crescente dos números é:",n1,n4,n2,n3)
    else:
       print("A ordem crescente dos números é:",n4,n1,n2,n3)

# %%
# 24-)
n=int(input("Digite um valor inteiro:"))
if (n%2==0 and n%3==0):
  print("Divisivel por 2 e 3.")
else:
  print("Não é divisivel por 2 e 3.")

# %%
# 25-)
hi=int(input("Digite a hora de inicio:"))
mi=int(input("Digite os minutos de inicio:"))
hf=int(input("Digite a hora final:"))
mf=int(input("Digite os minutos de fim:"))
inicio_min=((hi*60)+mi)
fim_min=((hf*60)+mf)
if fim_min<inicio_min:
  fim_min=(fim_min+(24*60))
  duracao=(fim_min-inicio_min)
  horas=(duracao/60)
  min=(duracao-(horas*60))
  print(horas,min)
else:
  duracao=(fim_min-inicio_min)
  horas=(duracao/60)
  min=(duracao-(horas*60))
  print(horas,min)

# %%
# 26-)
n1=int(input("Digite um número inteiro:"))
n2=int(input("Digite outro número inteiro:"))
if n1>n2:
  maior=(n1)
  menor=(n2)
  if maior%menor==0:
    print("Os números são divisiveis um pelo outro")
  else:
      print("Os anúmeros Não são divisiveis um pelo outro")

else:
  menor=(n1)
  maior=(n2)
  if maior%menor==0:
    print("Os números são divisiveis um pelo outro")
  else:
      print("Os números Não são divisiveis um pelo outro")

# %%
# 27-)
numero_de_voltas=int(input("Digite o número de voltas:"))
extensao_circuito=int(input("Digite a extensão do circuito(metros):"))
tempo=int(input("Digite a duração(minutos):"))
total_metros=(numero_de_voltas*extensao_circuito)
total_km=(total_metros/1000)
tempo_total=(tempo/60)
velocidade_media=(total_km/tempo_total)
print("A velocidade média é:",velocidade_media)

# %%
# 28-)
venda_mensal=int(input("Digite o Valor da venda Mensal:"))
preco_atual=int(input("Digite o Valor do preço Atual:"))
if venda_mensal<500 and preco_atual<30 :
  preco_atual=(preco_atual+(preco_atual*0.10))
  print("O novo Preço será:",preco_atual)
else:
    if venda_mensal>=500 and venda_mensal<1000 and preco_atual>=30 and preco_atual<80:
      preco_atual=(preco_atual+(preco_atual*0.15))
      print("O novo Preço será:",preco_atual)
    else:
      preco_atual=(preco_atual-(preco_atual*0.5))
      print("O novo Preço será:",preco_atual)

# %%
# 29-)
poupanca=float(input("Digite o quanto investiu em poupança(Se não investiu digite ,0)"))
renda_fixa=float(input("Digite o quanto investiu em Renda fixa(Se não investiu digite ,0)"))
if renda_fixa<poupanca:
  lucro=((poupanca*3)/100)
  poupanca=(poupanca+lucro)
  print("O valor final é:",poupanca)
else:
   lucro=((renda_fixa*5)/100)
   renda_fixa=(renda_fixa+lucro)
   print("O valor final é:",renda_fixa)

# %%
# 31-)
r=(0)
n1=(10)
while n1<= 50:
  r=(n1*n1+r)
  n1=(n1+1)
print("A soma dos quadrados dos números entre 10 e 50 é:", r)

# %%
# 32-)
n=int(input("Digite um número inteiro:"))
n1=(1)
n2=(2)
while n2<=n:
  n1=(n1*n2)
  n2=(n2+1)
  print (n1)

# %%
# 33-)
n=float(input("Digite um valor:"))
n1=1
r=0
while n1<=n:
  v=(r)
  r=((1/n1)+r)
  print (v)
  n1=(n1+1)

# %%
# 34-)
numero=int(input("Digite um número:"))
tabuada=1
while tabuada<=10:
  n1=(numero*tabuada)
  print(n1)
  tabuada=(tabuada+1)

# %%
# 35-)
n1=int(input("Digite um número:"))
n2=int(input("Digite outro número:"))
r=0
if n1>n2:
  m=(n1)
  n=(n2)
else:
  m=(n2)
  n=(n1)
  while n<=m:
      if n%2==0:
        n=(n+1)
      else:
        v=(n)
        r=(v+r)
        print(r)
        n=(n+1)

# %%
# 36-)
n=int(input("Digite um número:"))
i=(1)
res=(0)
n2=(1)
r=(1)
while i and r <=n:
  n2=(i*n2)
  res=((r/n2)+res)
  print(f"{res :.2f}")
  i=(i+1)
  r=(r+1)

# %%
# 37-)
n1=1
n2=1
res=1
while res<=21:
  i=(res)
  res=(n1+res)
  print(res)
  n1=(i)

# %%
# 38-)
i=(1)
maior=(0)
menor=(0)
while i<=100:
  n=int(input("Digite um Número inteiro:"))
  if n>maior:
    maior=(n)
    i=(i+1)
  else:
    if n<menor:
      menor=(n)
      i=(i+1)
    else:
      i=(i+1)
print("O maior valor é:",maior)
print("O menor valor é:",menor)

# %%
# 39-)
n=(1)
i=(0)
while i<64:
  i=(i+1)
  q=(2*n)
  n=(q)
print("Total de grãos é:",q)

# %%
# 40-)
inicio=int(input("Digite o primeiro número inteiro: "))
fim=int(input("Digite o segundo número inteiro: "))
if inicio>fim:
    temp=(inicio)
    inicio=(fim)
    fim=(temp)
num=(inicio+1)
print("Números primos entre", inicio, "e", fim, ":")
while num<fim:
    if num<2:
        num=(num+1)
    else:
        i=(2)
        primo=(1)
        while i*i<=num:
            if num%i==0:
                primo=(0)
            i=(i+1)
        if primo==1:
            print(num)
        num=(num+1)

# %%
# 41-)
dado1=(1)
while dado1<=6:
    dado2=(1)
    while dado2<=6:
        if dado1+dado2==7:
            print("Dado 1:", dado1, "Dado 2:", dado2)
        dado2=(dado2+1)
    dado1=(dado1+1)

# %%
# 42-)
n1=(1)
r=(0)
while n1<=50:
  n2=((n1*2)-1)
  r=((n1/n2)+r)
  n1=(n1+1)
print(round(r,2))

# %%
# 43-)
a=float(1.10)
m=float(1.50)
ca=float(0.03)
cm=float(0.02)
anos=(0)
while m >= a:
    a=(a+ca)
    m=(m+cm)
    anos=(anos+1)
    if a>m:
      print("Depois de",anos,"anos")
      print("O tamanho de Anna é:",round(a,2),"Metros")
      print("O tamanho de Maria é:",round(m,2),"Metros")

# %%
# 44-)
base=int(input("Digite a base:"))
expoente=int(input("Digite o expoente:"))
i=(1)
resultado=(0)
b1=(base)
while expoente>i:
  base=(base*b1)
  resultado=(base)
  i=(i+1)
  print(resultado)
  if expoente==i:
    print("O resultado é:",resultado)

# %%
# 45-)
n1=(1)
m=(0)
while n1<=15:
  n2=(n1*n1)
  r=(n1/n2)
  if n1 % 2==0:
    m=(m-r)
    print(round(m,2))
    n1=(n1+1)
  else:
    m=(m+r)
    print(round(m,2))
    n1=(n1+1)

# %%
# 17 ao 29 procedimento

# %%
# 17-) Procedimento
tp=int(input("Tempo de percurso(horas):"))
vm=int(input("Velocidade média:"))

def litros_gastos(tp,vm):
    dt=(tp*vm)
    lg=(dt/12)
    print(f"A quantidade de Litros gastos será:{lg :.2f}")

litros_gastos(tp, vm)

# %%
# 18-) Procedimento
v1=int(input("Digite o Valor 1:"))
v2=int(input("Digite o Valor 2:"))

def maior_e_diferenca(v1,v2):
    if v1 > v2:
        maior=(v1)
        resultado=(v1-v2)
    else:
        maior=(v2)
        resultado=(v2-v1)
    print("O maior valor é:",maior)
    print("A Diferença entre os valores é:",resultado)

maior_e_diferenca(v1,v2)

# %%
# 19-) Procedimetno
n1=float(input("Digite um número:"))
n2=float(input("Digite outro número:"))

def maior_numero_real(n1,n2):
    if n1 > n2:
        ma=(n1)
    else:
        ma=(n2)
    print("O maior número Real é:",ma)

maior_numero_real(n1,n2)

# %%
#Raiz ex 20-)
import math

# %%
# 20-) Procedimento
import math

a=int(input("Digite valor A:"))
b=int(input("Digite valor B:"))
c=int(input("Digite valor C:"))

def resultado_equacao(a,b,c):
    delta = ((b*b) - 4*a*c)
    if delta < 0:
        print("A equação não possui raízes reais.")
    else:
        x1 = (-b + math.sqrt(delta)) / (2*a)
        x2 = (-b - math.sqrt(delta)) / (2*a)
        print("O resultado da equação é: x1 =", x1, "e x2 =", x2)

resultado_equacao(a,b,c)

# %%
# 21-) Procedimento
n1=float(input("Digite a primeira nota:"))
n2=float(input("Digite a segunda nota:"))
n3=float(input("Digite a terceira nota:"))
n4=float(input("Digite a quarta nota:"))

def media_nota(n1,n2,n3,n4):
    media = ((n1+n2+n3+n4)/4)
    if media >= 6:
        print("Você foi Aprovado, sua nota foi:", media)
    elif 3 <= media < 6:
        print("Você está de Exame, sua nota foi:", media)
    else:
        print("Você está Retido, sua nota foi:", media)

media_nota(n1,n2,n3,n4)

# %%
# 22-) Procedimento
n1=int(input("Digite um número inteiro:"))
n2=int(input("Digite outro número inteiro:"))

def ordem_crescente(n1,n2):
    if n1 > n2:
        print("A ordem crescente dos números é:", n2, n1)
    else:
        print("A ordem crescente dos números é:", n1, n2)

ordem_crescente(n1,n2)

# %%
# 23-) Procedimento
n1=int(input("Digite um número:"))
n2=int(input("Digite um número (valor maior que o primeiro):"))
n3=int(input("Digite um número (valor maior que o segundo):"))
n4=int(input("Digite um número aleatório:"))

def ordem_numero(n1,n2,n3,n4):
    if n4 > n3:
        print("A ordem crescente dos números é:", n1, n2, n3, n4)
    elif n2 < n4 < n3:
        print("A ordem crescente dos números é:", n1, n2, n4, n3)
    elif n1 < n4 < n2:
        print("A ordem crescente dos números é:", n1, n4, n2, n3)
    else:
        print("A ordem crescente dos números é:", n4, n1, n2, n3)

ordem_numero(n1,n2,n3,n4)

# %%
# 24-) Procedimento
n=int(input("Digite um valor inteiro:"))

def divisivel(n):
    if (n % 2 == 0 and n % 3 == 0):
        print("Divisível por 2 e 3.")
    else:
        print("Não é divisível por 2 e 3.")

divisivel(n)

# %%
# 25-) Procedimento
hi=int(input("Digite a hora de início:"))
mi=int(input("Digite os minutos de início:"))
hf=int(input("Digite a hora final:"))
mf=int(input("Digite os minutos de fim:"))

def duracao_jogo(hi,mi,hf,mf):
    inicio_min = ((hi*60) + mi)
    fim_min = ((hf*60) + mf)
    if fim_min < inicio_min:
        fim_min = (fim_min + (24*60))
        duracao = (fim_min - inicio_min)
        horas = int(duracao / 60)
        minutos = int(duracao - (horas * 60))
        print("A duração do jogo foi de",horas,"hora(s) e",minutos,"minuto(s).")
    else:
        duracao = (fim_min - inicio_min)
        horas = int(duracao / 60)
        minutos = int(duracao - (horas * 60))
        print("A duração do jogo foi de",horas,"hora(s) e",minutos,"minuto(s).")

duracao_jogo(hi,mi,hf,mf)

# %%
# 26-) Procedimento
n1=int(input("Digite um número inteiro:"))
n2=int(input("Digite outro número inteiro:"))

def maior_numero_multiplo(n1,n2):
    if n1 > n2:
        maior=(n1)
        menor=(n2)
        if maior % menor == 0:
            print("Os números são divisíveis um pelo outro.")
        else:
            print("Os números não são divisíveis um pelo outro.")
    else:
        menor=(n1)
        maior=(n2)
        if maior % menor == 0:
            print("Os números são divisíveis um pelo outro.")
        else:
            print("Os números não são divisíveis um pelo outro.")

maior_numero_multiplo(n1,n2)

# %%
# 27-) Procedimento
numero_de_voltas=int(input("Digite o número de voltas:"))
extensao_circuito=int(input("Digite a extensão do circuito (metros):"))
tempo=int(input("Digite a duração (minutos):"))

def velocidade_media(numero_de_voltas,extensao_circuito,tempo):
    total_metros = (numero_de_voltas * extensao_circuito)
    total_km = (total_metros / 1000)
    tempo_total = (tempo / 60)
    velocidade_media = (total_km / tempo_total)
    print("A velocidade média é:",velocidade_media)

velocidade_media(numero_de_voltas,extensao_circuito,tempo)

# %%
# 28-) Procedimento
venda_mensal=int(input("Digite o Valor da venda Mensal:"))
preco_atual=int(input("Digite o Valor do preço Atual:"))

def novo_preco(venda_mensal,preco_atual):
    if venda_mensal < 500 and preco_atual < 30:
        preco_atual = (preco_atual + (preco_atual * 0.10))
        print("O resultado do novo preço será:",preco_atual)
    elif venda_mensal >= 500 and venda_mensal < 1000 and preco_atual >= 30 and preco_atual < 80:
        preco_atual = (preco_atual + (preco_atual * 0.15))
        print("O resultado do novo preço será:",preco_atual)
    else:
        preco_atual = (preco_atual - (preco_atual * 0.5))
        print("O resultado do novo preço será:",preco_atual)

novo_preco(venda_mensal,preco_atual)

# %%
# 29-) Procedimento
poupanca=int(input("Digite o quanto investiu em poupança (Se não investiu digite 0):"))
renda_fixa=int(input("Digite o quanto investiu em Renda fixa (Se não investiu digite 0):"))

def lucro_total(poupanca,renda_fixa):
    if renda_fixa < poupanca:
        lucro=((poupanca*3)/100)
        poupanca=(poupanca+lucro)
        print("O lucro total será:",poupanca)
    else:
        lucro=((renda_fixa*5)/100)
        renda_fixa=(renda_fixa+lucro)
        print("O lucro total será:",renda_fixa)

lucro_total(poupanca,renda_fixa)

# %%
# 31 ao 45 função

# %%
# 31-) Função
n1=10
n2=150
def res(n1,n2):
  while n1<=n2:
    r=(n1*n1)
    n1=(n1+1)
  return r
resultado=(res(n1,n2))
print(resultado)

# %%
# 32-) Função
n=int(input("Digite um número inteiro:"))
n1=1
n2=2
def fatorial(n,n1,n2):
  while n2<=n:
    n1 = (n1 * n2)
    n2 = (n2 + 1)
  return n1
resultado_fatorial=(fatorial(n,n1,n2))
print (resultado_fatorial)

# %%
# 33-) Função
n=float(input("Digite um valor:"))
n1=1
r=0
def serie(n,n1,r):
  while n1<=n:
    v=(r)
    r=((1/n1)+r)
    n1 = (n1 + 1)
  return v
valor_final=(serie(n,n1,r))
print(valor_final)

# %%
# 34-) Função
numero=int(input("Digite um número:"))
tabuada=1
def tabuada_1_10(numero,tabuada):
  resultado = []
  while tabuada<=10:
    n1=(numero*tabuada)
    resultado.append(n1)
    tabuada=(tabuada+1)
  return resultado
valor_final=(tabuada_1_10(numero,tabuada))
print(valor_final)

# %%
# 35-) Função
n1=int(input("Digite um número:"))
n2=int(input("Digite outro número:"))
def soma_impares(n1,n2):
  if n1>n2:
    maior=(n1)
    menor=(n2)
  else:
    maior=(n2)
    menor=(n1)
  r=(0)
  n=(menor)
  while n <= maior:
        if n%2 !=0:
          r=(r+n)
        n=(n+1)
  return maior,r
maior, soma = soma_impares(n1, n2)
print("O maior número é:", maior)
print("A soma dos ímpares entre eles é:", soma)

# %%
# 36-) Função
n=int(input("Digite um número:"))
i=(1)
res=(0)
n2=(1)
r=(1)
def serie (n,i,res,n2,r):
  while i and r <= n:
    n2=(i*n2)
    res=((r/n2)+res)
    i=(i+1)
    r=(r+1)
  return res
resultado=(serie (n,i,res,n2,r))
print(f"{resultado :.2f}")

# %%
# 37-) Função
n1=1
n2=1
res=1
def serie(n1,n2,res):
  resultado2 = []
  while res<=21:
    i=(res)
    res=(n1+res)
    resultado2.append(i)
    n1=(i)
  return resultado2

resultado=(serie(n1,n2,res))
print(resultado)

# %%
# 38-) Função
i=(1)
maior=(1)
menor=(1201)
def maior_menor(i,maior,menor):
  while i<=5:
    n=int(input("Digite um Número inteiro:"))
    if n>maior:
      maior=(n)
      i=(i+1)
    else:
      if n<menor:
        menor=(n)
        i=(i+1)
      else:
        i=(i+1)
  return menor , maior
menor_valor,maior_valor=maior_menor(i,maior,menor)
print("O menor valor é:",menor_valor)
print("O maior valor é:",maior_valor)

# %%
# 39-) Função
n=(1)
i=(0)
def segmento(n,i):
  resultado=[]
  while i<64:
    i=(i+1)
    q=(2*n)
    n=(q)
    resultado.append(q)
  return resultado
resultado1=(segmento(n,i))
print(resultado1)

# %%
# 40-) Função
def primo(inicio, fim):
    if inicio>fim:
        temp=(inicio)
        inicio=(fim)
        fim=(temp)
    num=(inicio+1)
    print("Números primos entre", inicio, "e", fim, ":")

    while num<fim:
        if num<2:
            num=(num+1)
        else:
            i=(2)
            eh_primo=(1)
            while i*i<=num:
                if num % i== 0:
                    eh_primo=(0)
                i=(i+1)
            if eh_primo==1:
                print(num)
            num=(num+1)
inicio = int(input("Digite o primeiro número inteiro: "))
fim = int(input("Digite o segundo número inteiro: "))
primo(inicio, fim)

# %%
# 41-) Função
n1=(1)
n2=(6)
def dados(n1, n2):
    resultado=[]
    while n1<=6:
        if n1+n2==7:
            resultado.append((n1, n2))
        n1=(n1+1)
        n2=(n2-1)
    return resultado
res=dados(n1,n2)
print("Combinações dos dados com soma igual a 7:")
for par in res:
    print("Dado 1:",par[0],"Dado 2:",par[1])

# %%
# 42-) Função
n1=(1)
r=(0)
def serie(n1,r):
  while n1<=50:
    n2=((n1*2)-1)
    r=((n1/n2)+r)
    n1=(n1+1)
  return r
resultado=(serie(n1,r))
print(f"{resultado :.2f}")

# %%
# 43-) Função
a=float(1.10)
m=float(1.50)
ca=float(0.03)
cm=float(0.02)
anos=(0)
def idade_idade(a,m,ca,cm,anos):
  while m >= a:
      a=(a+ca)
      m=(m+cm)
      anos=(anos+1)
      if a>m:
        return anos,a,m
anos_idade,aa,mm=idade_idade(a,m,ca,cm,anos)
print("Depois de",anos_idade,"anos")
print("Tamanho de Anna é:", round(aa, 2),"Metros")
print("Tamanho de Maria é:", round(mm, 2),"Metros")

# %%
# 44-) Função
base=int(input("Digite a base:"))
expoente=int(input("Digite o expoente:"))
i=(1)
resultado=(0)
b1=(base)
def serie(base,expoente,i,resultado,b1):
  while expoente>i:
    base=(base*b1)
    resultado=(base)
    i=(i+1)
    print(resultado)
    if expoente==i:
      return resultado
resultado_conta=(serie(base,expoente,i,resultado,b1))
print("O resultado é:",resultado_conta)

# %%
# 45-) Função
n1=(1)
m=(0)
def serie(n1,m):
  while n1<=15:
    n2=(n1*n1)
    r=(n1/n2)
    if n1 % 2==0:
      m=(m-r)
      n1=(n1+1)
      print(round(m,2))
    else:
      m=(m+r)
      n1=(n1+1)
      print(round(m,2))
  return m
mm=(serie(n1,m))
print(round(mm,2))

# %%
# recursiva
def fatorial(n):
  if n==1:
    return 1
  else:
    return n * fatorial(n - 1)
def soma_fatorial(n,i):
  if n==0:
    return 0
  else:
    return i / fatorial(n) + soma_fatorial(n - 1 , i + 1)
print(soma_fatorial(5,1))

# %%
# recursiva
def soma(n):
  if n==0:
    return 1
  else:
    return 2 ** n  + soma(n - 1)
print(soma(5))

# %%
# Recursiva
def soma(n,i):
  if n==0:
    return 0
  else:
    return i/n**i + soma(n - 1, i + 1)
print(soma(5,1))

# %%
# 1-) Função Recursiva
def soma_lista(n):
  if n==0:
    return 0
  else:
    return n + soma_lista(n - 1)
print(soma_lista(100))

# %%
# 2-) Função Recursiva
def soma_lista(n):
  if n==0:
    return 0
  else:
    return (n) + soma_lista(n - 1)
           # 5 + 4 + 3 + 2 + 1 + 0
print(soma_lista(5))

# %%
# 3-) Função Recursiva
def soma_lista(n):
  if n==0:
    return 0
  else:
    return 1/n + soma_lista(n - 1)
print(soma_lista(5))

# %%
# 4-) Função Recursiva

def soma_lista(n,i=1):
  if n==0:
    return 0
  else:
    return n / i + soma_lista(n - 1, i + 1)
print(soma_lista(5))

# %%
# 5-) Função Recursiva
def fatorial(n):
  if n==1:
    return 1
  else:
    return n * fatorial(n - 1)
def soma_fatorial(n):
  if n==1:
    return 1
  else:
    return fatorial(n) + soma_fatorial(n - 1)
print(soma_fatorial(5))

# %%
# 1-) Vetores
vet=[]
i=(0)
n1=(0)
n2=(0)
d=(0)
r=(0)
while i<50:
  i=(i+1)
  n=int(input("Digite um número:"))
  vet.append(n)
  if n>=10 and n<=200 :
    n=(n1+n)
    n1=(n)
    d=(d+1)
    r=(n1/d)

  if n % 2 != 0:
    n=(n2+n)
    n2=(n)
if r>0:
# 1-a
  print("A média dos valores entre 10 e 200 é:",r)
else:
  print("Nenhum valor entre 10 e 200")
# 1-b
if n2>0:
  print("A soma dos números impares é:",n2)
else:
  print("Nenhum valor impar foi encontrado")
print(vet)

# %%
# 2-) Vetores
vet=[]
i=(0)
n1=(0)
maior=(0)
menor=(0)
media=(0)
while i<5:
  n=int(input("Digite um número:"))
  vet.append(n)
  if i == 0:
        maior = n
        menor = n
  else:
        if n > maior:
            maior = n
        if n < menor:
            menor = n
  if n>=0:
    n=(n1+n)
    n1=(n)
  i=(i+1)
media=(n1/i)
# 2-a
print("O maior valor é:",maior)
print("O menor valor é:",menor)
# 2-b
print("A média dos números é:",media)
print(vet)

# %%
# 3-) Vetores
vt1=[]
vt2=[]
vt3=[]
i=(0)
n2=(0)
n1=(0)
while i<3:
  n1=int(input("Digite um número VET 1:"))
  vt1.append(n1)
  i=(i+1)
i=(0)
while i<3:
  n2=int(input("Digite um número VET 2:"))
  vt2.append(n2)
  i=(i+1)
vt3=(vt1+vt2)
print("Vetor 1:",vt1)
print("Vetor 2:",vt2)
print("Vetor 3:",vt3)

# %%
# 4-) Vetores
vet=[]
i=(0)
n=(0)
n1=(0)
media=(0)
m=(0)
acima=(0)
abaixo=(0)
while i<5:
  n=int(input("Digite uma nota:"))
  vet.append(n)
  n1=(n1+n)
  i=(i+1)
media=(n1/i)
while m<i:
  if media<vet[m]:
     acima=(acima+1)
  if media>vet[m]:
     abaixo=(abaixo+1)
  m=(m+1)
# a-)
print("A Média é:",media)
# b-)
print("A Quantidade de notas acima da média é:",acima)
# c-)
print("A Quantidade de notas abaixo da média é:",abaixo)
print(vet[abaixo])

# %%
# 5-) Vetores
vet = []
i = (0)
soma = (0)
while i < 20:
  n = int(input("Digite um número: "))
  vet.append(n)
  i = (i + 1)
i = (0)
while i < 11:
  soma = (soma + (vet[i] - vet[19 - i]))
  i = (i + 1)
print("A soma dos números é:", soma)

# %%
# 6-) Vetores
vet=[]
i=(0)
while i<20:
    n=int(input("Digite um número: "))
    vet.append(n)
    i += 1
i=(0)
while i<19:
    j=(i+1)
    while j<5:
        if vet[i]>vet[j]:
            aux=(vet[i])
            vet[i]=(vet[j])
            vet[j]=(aux)
        j += 1
    i += 1
print("A ordem crescente é:",vet)

# %%
# 7-) vetores
vet=[]
i=(0)

while i<20:
    n=int(input("Digite um número: "))
    vet.append(n)
    i=(i+1)
n1=int(input("Digite um número para buscar no vetor: "))
i=(0)
while i<20:
    if vet[i] == n1:
        print("O número está no vetor na posição:",i)
    i=(i+1)

# %%
# 8-) Matrizes
mat = []
i = (0)
while i < 4:
  linha = []
  j = (0)
  while j < 3:
    n = int(input("Digite um número: "))
    linha.append(n)
    j = (j + 1)
  mat.append(linha)
  i = (i + 1)

i = (0)
j = (0)
soma = (0)
while j < 3:
  i = (0)
  while i < 4:
    soma = (soma + mat[i][j])
    i = (i + 1)
  print("A quantidade de produtos da semana", (j + 1), "vendidos é:", soma)
  soma = (0)
  j = (j + 1)

soma = (0)
i = (0)
j = (0)
while i < 4:
  j = (0)
  while j < 3:
    soma = (soma + mat[i][j])
    j = (j + 1)
  print("A quantidade de produtos do vendedor", (i + 1), "vendidos é:", soma)
  soma = (0)
  i = (i + 1)

i = (0)
j = (0)
soma = (0)
while i < 4:
  j = (0)
  while j < 3:
    soma = (soma + mat[i][j])
    j = (j + 1)
  i = (i + 1)
print("Soma total é:", soma)

# %%
# 9-) Matrizes
mat = []
i = (0)
while i < 4:
  linha = []
  j = (0)
  while j < 4:
    n = int(input("Digite um número: "))
    linha.append(n)
    j = (j + 1)
  mat.append(linha)
  i = (i + 1)
i = (0)
j = (0)
mul = (0)
while i < 4:
  j = (0)
  while j < 4:
    if i == j:
      mat[i][j] = (4 ** mul)
      mul = (mul + 1)
    j = (j + 1)
  i = (i + 1)
print(mat)

# %%
# 10-) Matrizes
mat=[]
i=(0)
linha1=[]
while i<8:
  linha1.append(i+1)
  i=(i+1)
mat.append(linha1)
linha2=[]
j=(0)
while j<8:
  n=int(input("Digite o valor da casa {}: ".format(j + 1)))
  linha2.append(n)
  j=(j+1)
mat.append(linha2)
k=(0)
soma=(0)
while k<8:
  soma=soma+mat[1][k]
  k=(k+1)
print("Casa: ", mat[0])
print("Valor:", mat[1])
print("Soma dos valores:", soma)

# %%
# 11-) Matriz
mat = []
size = 8
i = (0)
while i < size:
    linha = []
    j = (0)
    while j < size:
        dist_top = i
        dist_left = j
        dist_bottom = (size - 1) - i
        dist_right = (size - 1) - j
        dist = dist_top
        if dist_left < dist:
            dist = dist_left
        if dist_bottom < dist:
            dist = dist_bottom
        if dist_right < dist:
            dist = dist_right
        val = (1 + dist)
        if val > 4:
            val = 4
        linha.append(val)
        j = (j + 1)
    mat.append(linha)
    i = (i + 1)
i = (0)
while i < size:
    print(mat[i])
    i = (i + 1)

# %%
# 12-) Matrizes
mat=[]
vet=[0, 0, 0, 0, 0, 0, 0]
i=(0)
while i<8:
    linha=[]
    j=(0)
    while j<8:
        n=int(input("Digite um número (1 a 7): "))
        linha.append(n)
        j=(j+1)
    mat.append(linha)
    i=(i+1)
i=(0)
while i<8:
    j=(0)
    while j<8:
        vet[mat[i][j]-1]=vet[mat[i][j]-1]+1
        j=(j+1)
    i=(i+1)
print("peão:", vet[0])
print("torre:", vet[1])
print("bispo:", vet[2])
print("cavalo:", vet[3])
print("rainha:", vet[4])
print("rei:", vet[5])
print("vazio:", vet[6])
